# %% [markdown]
# <h1>Advent of Code 2025 - Day 1</h1>
#
# <h3> Day 1 Part 1 - Problem</h3>
#
# <p>You arrive at the secret entrance to the North Pole base ready to start decorating. Unfortunately, the password seems to have been changed, so you can't get in. A document taped to the wall helpfully explains:
#
# "Due to new security protocols, the password is locked in the safe below. Please see the attached document for the new combination."
#
# The safe has a dial with only an arrow on it; around the dial are the numbers 0 through 99 in order. As you turn the dial, it makes a small click noise as it reaches each number.
#
# The attached document (your puzzle input) contains a sequence of rotations, one per line, which tell you how to open the safe. A rotation starts with an L or R which indicates whether the rotation should be to the left (toward lower numbers) or to the right (toward higher numbers). Then, the rotation has a distance value which indicates how many clicks the dial should be rotated in that direction.
#
# So, if the dial were pointing at 11, a rotation of R8 would cause the dial to point at 19. After that, a rotation of L19 would cause it to point at 0.
#
# Because the dial is a circle, turning the dial left from 0 one click makes it point at 99. Similarly, turning the dial right from 99 one click makes it point at 0.
#
# So, if the dial were pointing at 5, a rotation of L10 would cause it to point at 95. After that, a rotation of R5 could cause it to point at 0.
#
# The dial starts by pointing at 50.
#
# You could follow the instructions, but your recent required official North Pole secret entrance security training seminar taught you that the safe is actually a decoy. The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.
#
# For example, suppose the attached document contained the following rotations:
# <ul>
#     <li>L68</li>
#     <li>L30</li>
#     <li>R48</li>
#     <li>L5</li>
#     <li>R60</li>
#     <li>L55</li>
#     <li>L1</li>
#     <li>L99</li>
#     <li>R14</li>
#     <li>L82</li>
# </ul>
# Following these rotations would cause the dial to move as follows:
#
# <ul>
# <li>The dial starts by pointing at 50.</li>
# <li>The dial is rotated L68 to point at 82.</li>
# <li>The dial is rotated L30 to point at 52.</li>
# <li>The dial is rotated R48 to point at 0.</li>
# <li>The dial is rotated L5 to point at 95.</li>
# <li>The dial is rotated R60 to point at 55.</li>
# <li>The dial is rotated L55 to point at 0.</li>
# <li>The dial is rotated L1 to point at 99.</li>
# <li>The dial is rotated L99 to point at 0.</li>
# <li>The dial is rotated R14 to point at 14.</li>
# <li>The dial is rotated L82 to point at 32.</li>
#
# </ul>
# Because the dial points at 0 a total of three times during this process, the password in this example is 3.
#
# Analyze the rotations in your attached document. What's the actual password to open the door?</p>

# %% [markdown]
# <h3> Day 1 Part 1 - Answer </h3>

# %% [markdown]
# <p> So, we need to simulate a moving dial that loops on itself. Or do we? We only need to acquire information when the dial reaches zero. I see an easier way to find out:</p>

# %%
print(100%100)
print(0%100)
print(-100%100)
# Out:
# 0
# 0
# 0

# %% [markdown]
# <p> As you can see, by using the modulo we don't actually have to simulate a dial, instead we can just do a regular integer. Now all we have to do is parse the file and count the occurrences of zero.</p>

# %%
#Open our file
f = open("day1input25.txt")
#We start from the 50 mark
start = 50
#Set password clicks to 0
password = 0
#For each row in our file
for x in f:
    #Taking the number part of a row
    turns = x[1:len(x)]
    #Check if we turn right
    if x[0] == "R":
        #Increase our current number
        start += int(turns)
    #If not right, we turn left
    else:
        #Descrease our current number
        start -= int(turns)
    #Check if we hit a zero
    if start%100 == 0:
        #Increment our password when zero was hit
        password += 1

print(password)
# Out:
# 1031

# %% [markdown]
# <p> And that was the correct answer! Onwards to part! </p>

# %% [markdown]
# <h3> Day 1 - Part 2 - Problem</h3>
#
# <p> You're sure that's the right password, but the door won't open. You knock, but nobody answers. You build a snowman while you think.
#
# As you're rolling the snowballs for your snowman, you find another security document that must have fallen into the snow:
#
# "Due to newer security protocols, please use password method 0x434C49434B until further notice."
#
# You remember from the training seminar that "method 0x434C49434B" means you're actually supposed to count the number of times any click causes the dial to point at 0, regardless of whether it happens during a rotation or at the end of one.
#
# Following the same rotations as in the above example, the dial points at zero a few extra times during its rotations:abs
#
# <ul>
#     <li>The dial starts by pointing at 50.</li>
#     <li>The dial is rotated L68 to point at 82; during this rotation, it points at 0 once.</li>
#     <li>The dial is rotated L30 to point at 52.</li>
#     <li>The dial is rotated R48 to point at 0.</li>
#     <li>The dial is rotated L5 to point at 95.</li>
#     <li>The dial is rotated R60 to point at 55; during this rotation, it points at 0 once.</li>
#     <li>The dial is rotated L55 to point at 0.</li>
#     <li>The dial is rotated L1 to point at 99.</li>
#     <li>The dial is rotated L99 to point at 0.</li>
#     <li>The dial is rotated R14 to point at 14.</li>
#     <li>The dial is rotated L82 to point at 32; during this rotation, it points at 0 once.</li>
# </ul>
#
# In this example, the dial points at 0 three times at the end of a rotation, plus three more times during a rotation. So, in this example, the new password would be 6.
#
# Be careful: if the dial were pointing at 50, a single rotation like R1000 would cause the dial to point at 0 ten times before returning back to 50!
#
# Using password method 0x434C49434B, what is the password to open the door?
# </p>

# %% [markdown]
# <h3> Day 1 - Part 2 - Answer</h3>

# %% [markdown]
# <p> Well, our first part solution cannot directly take this into account. Now we need to do some comparisons between the moves to see how many times we move through zeroes and hundreds. </p>

# %% [markdown]
# <p> We can do this easily by for example: if we were to turn R256 when we are at 50:
# <ul>
#     <li>Since 256 is over 100, we can just take the 2 in the hundreds place, add it to our password</li>
#     <li>Then with the 56, we just run it like normally and additionally check if we cross a 100 mark.</li>
# </ul>
#
# There are four possible occurrences here: Existing number both positive and negative or new turn right or left, let's simulate what we would need to do:
#
# <ul>
#     <li>Existing 90, turn R20: We need to see if existing + turn > 100</li>
#     <li>Existing -10, turn R20: We need to see if existing + turn > 0</li>
#     <li>Existing 10, turn L20: We need to see if existing - turn < 0</li>
#     <li>Existing -90 turn L20, We need to see if existing - turn < 100</li>
# </ul>
#
# These rules get a bit complicated, so let's move a step at a time and see when we hit a zero
#
# </p>

# %%
#Open our file
f = open("day1input25.txt")
#We start from the 50 mark
start = 50
#Set password clicks to 0
password = 0
#For each row in our file
for x in f:
    turns = x[1:len(x)]
    #Check if we turn right
    if x[0] == "R":
        #Increase our current number step by step
        for i in range(int(turns)):
            start += 1
            if start%100 == 0:
                #Increment our password when zero was hit
                password += 1
    #If not right, we turn left
    else:
        #Decrease our current number step by step
        for i in range(int(turns)):
            start -= 1
            if start%100 == 0:
                #Increment our password when zero was hit
                password += 1

print(password)
# Out:
# 5831

# %% [markdown]
# <p> And that's our correct answer, I would have liked to do this more efficiently but ran into some niche edge cases, sometimes simple is better at the cost of some computing power.</p>
